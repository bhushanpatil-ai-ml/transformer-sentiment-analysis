# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
train_df = pd.read_csv("../data/processed/train_processed.csv")
test_df = pd.read_csv("../data/processed/test_processed.csv")

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

train_df.head()

# %%
print(train_df.isnull().sum())

# %%
train_df["label"].value_counts()

# %%
train_df["label"].value_counts().plot(kind="bar")
plt.title("Class Distribution")
plt.xlabel("Sentiment Label")
plt.ylabel("Count")
plt.show()

# %%
train_df["review_length"].describe()

# %%
plt.figure(figsize=(10, 5))
plt.hist(train_df["review_length"], bins=50)
plt.title("Review Length Distribution")
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="label", y="review_length", data=train_df)
plt.title("Review Length by Sentiment Class")
plt.show()

# %%
train_df[["text", "clean_review", "label"]].head(10)

# %%
plt.figure(figsize=(6, 4))
train_df["label"].value_counts().plot(kind="bar")
plt.title("Class Distribution")
plt.xlabel("Sentiment Label")
plt.ylabel("Count")
plt.tight_layout()
plt.savefig("../outputs/plots/class_distribution.png")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(train_df["review_length"], bins=50)
plt.title("Review Length Distribution")
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.tight_layout()
plt.savefig("../outputs/plots/review_length_distribution.png")
plt.show()
